# %%
path = "annotation_result/case_000_00/masks"
import os
import cv2

mask_list = os.listdir(path)
for mask in mask_list:
    mask_path = os.path.join(path, mask)
    img = cv2.imread(mask_path)
    print(img.shape)
    # 흑백으로 변환 저장
    # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # cv2.imwrite(mask_path, img)
# Out:
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# ...

# %%
import os
import subprocess
import re
from datetime import timedelta

def get_video_duration(filepath):
    command = f"ffmpeg -i {filepath} 2>&1 | grep 'Duration'"
    result = subprocess.run(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    output = result.stdout.decode('utf-8')
    match = re.search(r"Duration:\s*(\d+):(\d+):(\d+\.\d+)", output)
    if match:
        hours, minutes, seconds = map(float, match.groups())
        return timedelta(hours=hours, minutes=minutes, seconds=seconds)
    return timedelta(0)

def get_total_duration(directory):
    total_duration = timedelta()
    for filename in os.listdir(directory):
        if filename.endswith(('.mp4', '.mkv', '.avi', '.mov')):  # 필요한 파일 확장자만 포함
            filepath = os.path.join(directory, filename)
            duration = get_video_duration(filepath)
            total_duration += duration
            print(f"{filename}: {duration}")
    return total_duration

directory = '/home/uichan8/Desktop/project/SurgVU_project/Data/clips'
total_duration = get_total_duration(directory)

print(f"Total duration: {total_duration}")
# Out:
# case_084_01.mp4: 1:58:05.620000
# case_025_00.mp4: 0:03:47.870000
# case_057_14.mp4: 0:03:37.470000
# case_045_01.mp4: 1:10:03.680000
# case_051_03.mp4: 0:07:08.420000
# case_020_00.mp4: 0:09:00.870000
# case_105_03.mp4: 0:01:24.550000
# case_060_05.mp4: 1:06:46
# case_055_03.mp4: 0:01:06.080000
# case_002_15.mp4: 0:00:04.330000
# case_095_01.mp4: 0:05:04.520000
# case_077_07.mp4: 0:01:58.600000
# case_037_09.mp4: 0:01:46.800000
# case_103_10.mp4: 0:00:17.980000
# case_028_03.mp4: 0:35:16.700000
# case_092_08.mp4: 0:00:42.850000
# case_114_03.mp4: 0:02:42.720000
# case_008_11.mp4: 0:03:27.670000
# case_015_04.mp4: 0:18:17.070000
# case_003_16.mp4: 0:08:17.850000
# case_124_03.mp4: 0:00:07.620000
# case_054_05.mp4: 0:00:44.480000
# case_100_00.mp4: 0:10:25.870000
# case_027_02.mp4: 0:00:19.420000
# case_117_09.mp4: 0:00:17.770000
# case_017_04.mp4: 0:26:48.250000
# case_048_02.mp4: 1:31:54.870000
# case_074_14.mp4: 0:00:36.800000
# case_049_05.mp4: 0:00:15.100000
# ...

# %%
import os
import subprocess
import re

# 동영상 파일이 저장된 디렉토리 경로
directory = '/home/uichan8/Desktop/project/SurgVU_project/Data/clips'

# 총 프레임 수를 저장할 변수 초기화
total_frames = 0

# 디렉토리 내 모든 파일에 대해 반복
for filename in os.listdir(directory):
    if filename.endswith(".mp4"):  # mp4 파일만 처리
        filepath = os.path.join(directory, filename)
        
        # ffprobe를 사용하여 각 동영상의 총 프레임 수를 추출
        command = f"ffprobe -v error -select_streams v:0 -count_frames -show_entries stream=nb_read_frames -of default=nokey=1:noprint_wrappers=1 \"{filepath}\""
        result = subprocess.run(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        
        # 프레임 수 추출
        frames = int(result.stdout.decode('utf-8').strip())
        
        # 총 프레임 수에 더하기
        total_frames += frames

# 결과 출력
print(f"Total frames: {total_frames}")

# %%
# Out:
# {'needle driver', 'vessel sealer', 'clip applier ', 'stapler', 'synchroseal', 'bipolar dissector', 'monopolar curved scissors', 'bipolar forceps', 'prograsp forceps', 'permanent cautery hook/spatula', 'force bipolar', 'cadiere forceps', 'curved scissors', 'nan(camera in)'}

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/SurgVU/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df[0]
#
# ...
